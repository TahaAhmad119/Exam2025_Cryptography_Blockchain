# %% [markdown]
# **1. How was the password "santa" guessed?**
#
#
# The password "santa" might have been guessed due to weak security practices by the suspect. Here are some possible reasons:
#
# **1) Common passwords:** "santa" is a simple and predictable password that might be used by someone during the holiday season or as an easy-to-remember password.
#
# **2) Social engineering:** If the suspect has a connection to Christmas or often uses "santa" in usernames or email addresses, this could be an educated guess.
#
# **3) Brute-force attack:** The password might have been found using a dictionary attack with a wordlist containing commonly used words like "santa."
#
# **4) Reused passwords:** If the suspect had used "santa" elsewhere (e.g., in leaked databases), it could have been tested.

# %% [markdown]
# **2. Decrypting the message (msg.txt.asc) using the provided private key**
#
# To decrypt the message, follow these steps:
#
# First Save the Private Key into File:
#
# Copy the key and create a file named keyfile-secret.asc
#
# Now Import the Private key into GPG using this command:
#
#     *    gpg --import keyfile-secret.asc
#
# after runing this i enter the 'santa' as passpharse
#
# Now Decrypt the Encrypted message.txt.asc file using this command:
#
#     *    gpg --decrypt msg.txt.asc
#
# now i enter passpharse to decrpt it.
#
# gpg: invalid armor header: hF4D9TO5rerfDDcSAQdAZSBCwPrcVaqhccxGA8cFo9KllxjICpJaIYapLYM153Ew\n
# gpg: encrypted with cv25519 key, ID F533B9ADEADF0C37, created 2024-01-10
#       "Santa Claus <santa.claus@microsoft.com>"
# gpg: Note: secret key F533B9ADEADF0C37 expired at Wed Apr 10 01:47:05 2024 PKT
# When you give joy to other people, you get more joy in return.
